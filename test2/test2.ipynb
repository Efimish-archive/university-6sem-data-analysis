# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("c.csv")
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
len(df)
# Out:
# 16719

# %%
df.nunique().sort_values(ascending=False).filter(items=[
  "Publisher",
  "Genre",
  "Year_of_Release",
  "Platform",
])
# Out:
# Publisher          581
# Genre               12
# Year_of_Release     39
# Platform            31
# dtype: int64

# %%
round(df["EU_Sales"].mean(), 2)
# Out:
# np.float64(0.15)

# %%
round(df["EU_Sales"].std(), 2)
# Out:
# np.float64(0.5)

# %%
df2 = df.copy(True)
df2["Platform_Coded"] = df2["Platform"].map(lambda p: 1 if p == "PS2" else 0)
round(df2["Platform_Coded"].mean(), 2)
# Out:
# np.float64(0.13)

# %%
round(df[
  (df["Publisher"] == "Ubisoft")
  | (df["Publisher"] == "Activision")
]["Critic_Score"].mean(), 2)
# Out:
# np.float64(69.1)

# %%
df["Critic_Score"].isna().sum()
# Out:
# np.int64(8582)
