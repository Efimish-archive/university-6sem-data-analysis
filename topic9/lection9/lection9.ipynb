# %% [markdown]
# # Задание к лекции №9
#
# **Тема**: Разведочный анализ данных

# %%
# Подготовка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Определите, какие факторы в данных имеют распределение, которое отличается от равномерного.

# %%
df = pd.read_csv("uniform_and_not_data.csv")
df
# Out:
#             A         B         C         D         E
# 0   -0.216533  3.313403  3.664743 -0.047255  0.386616
# 1   -0.003454  3.854757 -5.088873 -0.725561  0.000033
# 2   -0.585603  7.018951 -1.380724  0.691111  0.355108
# 3    0.175861  1.493150  6.155430 -0.379548  0.650187
# 4    0.816606  6.293888  0.957381 -0.816596  0.066945
# ..        ...       ...       ...       ...       ...
# 995  0.350588  2.222234  2.845702  0.105276  0.017850
# 996  0.687375  8.626769  7.047696  1.763750  0.123616
# 997 -0.412029  2.121481 -7.713308 -0.132196  0.879443
# 998 -0.308407  3.199384  2.291067  0.340190  0.048669
# 999 -0.353134  5.391267 -4.294576 -0.601732  0.738216
#
# [1000 rows x 5 columns]

# %% [markdown]
# a - ravn
# b - no
# c - ravn
# d - no
# e - no

# %%
sns.histplot(df['E'])
# Out:
# <Axes: xlabel='E', ylabel='Count'>

# %%
Дана следующая таблица в формате csv. В таблице для каждого наблюдения представлены значения пяти факторов: A, B, C, D и E. Постройте корреляционную матрицу. В качестве ответа укажите наибольшее значение коэффициента корреляции с 6 знаками после запятой (В ответе целую и дробную часть отделите точкой).
Ваш ответ

# %%
df = pd.read_csv("many_factors_data.csv")
df
# Out:
#             A         B         C         D         E
# 0    0.464512  0.215771  0.211649  0.213262  0.460054
# 1   -0.968919  0.938804  0.349538  0.357078  0.591217
# 2    0.556104  0.309251  0.015493  0.015493  0.124470
# 3   -0.437593  0.191487 -0.186278 -0.187373  0.431600
# 4   -0.525049  0.275676  0.091514  0.091642  0.302513
# ..        ...       ...       ...       ...       ...
# 995 -0.752952  0.566936  0.268539  0.271876  0.518207
# 996  0.553369  0.306217 -0.218281 -0.220053  0.467206
# 997 -0.065149  0.004244 -0.056720 -0.056750  0.238159
# 998 -0.597293  0.356759  0.057675  0.057707  0.240157
# 999 -0.743315  0.552518  0.102271  0.102450  0.319798
#
# [1000 rows x 5 columns]

# %%
sns.matrix.clustermap(df)

# %%
# Экспорт в html
import subprocess
subprocess.run(["jupyter", "nbconvert", "--to", "html", __vsc_ipynb_file__.split("/")[-1]])
# Out:
# [NbConvertApp] Converting notebook questions8.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 11 image(s).
# [NbConvertApp] Writing 669259 bytes to questions8.html
# CompletedProcess(args=['jupyter', 'nbconvert', '--to', 'html', 'questions8.ipynb'], returncode=0)
